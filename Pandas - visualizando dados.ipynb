# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df2 = pd.read_csv("df2")

# %% [markdown]
# Folha de estilo:

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# a    10 non-null float64
# b    10 non-null float64
# c    10 non-null float64
# d    10 non-null float64
# dtypes: float64(4)
# memory usage: 400.0 bytes

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B')

# %% [markdown]
# O parametro c faz com que a cor mude a partir de uma variável:

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
O parametro c faz com que o tamanho mude a partir de uma variável:
# Out:
#   File "<ipython-input-20-d4b347949d49>", line 1
#     O parametro c faz com que o tamanho mude a partir de uma variável:
#               ^
# SyntaxError: invalid syntax

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']* 50)

# %%
df1.plot.box()

# %%
df2.plot.box()

# %%
# Out:
# array([[0.15509103, 0.3695202 ],
#        [0.05684379, 0.16545296],
#        [0.58749308, 0.06018273],
#        ...,
#        [0.44596753, 0.19708038],
#        [0.37425624, 0.98973773],
#        [0.19098268, 0.69841868]])

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A','B'])

# %%
df.head()
# Out:
#           A         B
# 0  0.187344  0.242936
# 1  0.425553  0.933602
# 2  0.171500  0.471837
# 3  0.988315  0.408167
# 4  0.045200  0.352610

# %%
df.plot.hexbin(x='A', y='B', gridsize=20, cmap='Blues') #gridsize aumenta tamanho dos hexagonos

# %%
df2['a'].plot.kde()

# %%
df2.plot.kde()
